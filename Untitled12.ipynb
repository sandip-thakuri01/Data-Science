# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/instagram_users_lifestyle.csv')

# %%
df.head()
# Out:
#    user_id   app_name  age      gender         country urban_rural  \
# 0        1  Instagram   51      Female           India       Rural
# 1        2  Instagram   64      Female  United Kingdom       Urban
# 2        3  Instagram   41      Female          Canada       Urban
# 3        4  Instagram   27  Non-binary     South Korea       Urban
# 4        5  Instagram   55        Male           India       Urban
#
#    income_level   employment_status education_level relationship_status  ...  \
# 0          High             Retired      Bachelor’s              Single  ...
# 1        Middle  Full-time employed           Other            Divorced  ...
# 2        Middle             Student      Bachelor’s   In a relationship  ...
# 3        Middle          Unemployed        Master’s   In a relationship  ...
# 4  Upper-middle  Full-time employed      Bachelor’s              Single  ...
#
#   last_login_date  average_session_length_minutes  content_type_preference  \
# ...

# %%
df.describe()
# Out:
#              user_id            age  exercise_hours_per_week  \
# count  577204.000000  577204.000000            577203.000000
# mean   288602.500000      39.017145                 7.142426
# std    166624.586725      15.290122                 3.991927
# min         1.000000      13.000000                 0.000000
# 25%    144301.750000      26.000000                 4.000000
# 50%    288602.500000      39.000000                 6.600000
# 75%    432903.250000      52.000000                 9.700000
# max    577204.000000      65.000000                24.000000
#
#        sleep_hours_per_night  perceived_stress_score  self_reported_happiness  \
# count          577203.000000           577203.000000            577203.000000
# mean                6.999804               20.000419                 5.492317
# std                 1.098503               11.821215                 2.869422
# min                 3.000000                0.000000                 1.000000
# ...

# %%
sample_df = df.sample(n=150, random_state=20)

# %%
sample_df.head()
# Out:
#         user_id   app_name  age  gender         country urban_rural  \
# 254627   254628  Instagram   61  Female   United States    Suburban
# 140748   140749  Instagram   63  Female           Japan       Urban
# 79480     79481  Instagram   28    Male           Other       Urban
# 384509   384510  Instagram   41  Female  United Kingdom       Urban
# 179909   179910  Instagram   26    Male           India    Suburban
#
#         income_level   employment_status education_level relationship_status  \
# 254627        Middle  Full-time employed    Some college              Single
# 140748  Lower-middle  Full-time employed    Some college             Married
# 79480   Lower-middle  Full-time employed    Some college             Married
# 384509        Middle             Student        Master’s             Married
# 179909        Middle             Retired     High school            Divorced
#
#         ... last_login_date  average_session_length_minutes  \
# ...

# %%
sample_df = df.sample(frac=0.1, random_state=42)

# %%
sample_df.head()
# Out:
#         user_id   app_name  age             gender        country urban_rural  \
# 269016   269017  Instagram   57             Female          Other       Urban
# 310201   310202  Instagram   49             Female          India       Rural
# 215098   215099  Instagram   49               Male          India       Rural
# 254829   254830  Instagram   20               Male  United States    Suburban
# 478164   478165  Instagram   56  Prefer not to say  United States       Urban
#
#         income_level   employment_status education_level relationship_status  \
# 269016        Middle             Retired      Bachelor’s             Married
# 310201           Low  Full-time employed     High school              Single
# 215098  Lower-middle          Freelancer     High school              Single
# 254829        Middle           Part-time     High school              Single
# 478164           Low  Full-time employed     High school              Single
#
# ...
